# %% [markdown]
# # MyDataMaster for use in another ipynb files

# %% [markdown]
# <b> I am processing my files here before running my model in another file

# %% [markdown]
# # Packages

# %%
# Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns

# Pretty display of variables
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"


## Plot styles
# %matplotlib inline
# plt.rcParams['figure.figsize'] = (15,5)
# plt.rcParams["font.family"] = 'DejaVu Sans'
# plt.rcParams["font.size"] = '12'
# plt.rcParams['image.cmap'] = 'rainbow'

# %%
from platform import python_version

print(python_version())
# Out:
# 3.8.8

# %% [markdown]
# #  Create directory

# %% [markdown]
# ## Method-1
# This method overwites existing directory and data in the directory

# %%
import os
import shutil
def createdir(path):
    if not os.path.exists(path):
        os.makedirs(path)
    else:
        shutil.rmtree(path)  # Removes all the subdirectories!
        os.makedirs(path)

# %%
# Directory
directory_Figures = 'Results/Figures'
directory_Numeric = 'Results/Numeric'

createdir(directory_Figures)
createdir(directory_Numeric)

# %% [markdown]
# ## Method-2

# %%
# # importing os module
# import os
# # Directory
# directory_Figures = 'Results/Figures'
# directory_Numeric = 'Results/Numeric'

# # Path
# parent_dir=os.getcwd()
# path = os.path.join(parent_dir, directory_Figures)
# path = os.path.join(parent_dir, directory_Numeric)
# # Create the directory
# os.mkdir(path)
# print("Directory '% s' created" % directory_Figures)
# print("Directory '% s' created" % directory_Numeric)

# %% [markdown]
# # Import dataset

# %%
# Load the dataset

dataset_orig = pd.read_excel('Data/Shear FRCM & SRG.xlsx', sheet_name = 'dataNEW3')
dataset_orig
# Out:
#        b      d       a/d    fc'     rohsx    fsx     rohsy    fsy  \
# 0    150  307.5  3.250000  37.50  2.170000  480.0  0.000000    0.0
# 1    150  307.5  3.250000  37.50  2.170000  480.0  0.000000    0.0
# 2    150  307.5  3.250000  37.50  2.170000  480.0  0.000000    0.0
# 3    150  307.5  3.250000  38.00  2.170000  480.0  0.000000    0.0
# 4    150  307.5  3.250000  37.50  2.170000  480.0  0.000000    0.0
# ..   ...    ...       ...    ...       ...    ...       ...    ...
# 168  150  242.0  3.305785  45.95  4.327263  526.2  0.268083  526.2
# 169  150  242.0  3.305785  45.95  4.327263  526.2  0.268083  526.2
# 170  150  242.0  3.305785  45.95  4.327263  526.2  0.268083  526.2
# 171  150  242.0  3.305785  45.95  4.327263  526.2  0.268083  526.2
# 172  150  242.0  3.305785  45.95  4.327263  526.2  0.268083  526.2
#
#      Fiber type     Ef   ffu  WS      rosf     hfe    V, ex
# 0             1   75.0  2300   1  0.626667  276.75   73.150
# 1             1   75.0  2300   2  0.626667  276.75   90.100
# 2             2  230.0  3800   1  0.489333  276.75   77.750
# 3             2  230.0  3800   2  0.489333  276.75   75.900
# 4             2  230.0  3800   1  1.177333  276.75  122.700
# ..          ...    ...   ...  ..       ...     ...      ...
# 168           3  270.0  5800   2  0.341250  300.00  248.760
# 169           3  270.0  5800   2  0.341250  300.00  236.120
# 170           3  270.0  5800   2  0.341250  300.00  252.790
# 171           3  270.0  5800   2  0.341250  300.00  237.360
# 172           3  270.0  5800   2  0.341250  300.00  229.015
#
# [173 rows x 15 columns]

# %%
dataset_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   b           173 non-null    int64
#  1   d           173 non-null    float64
#  2   a/d         173 non-null    float64
#  3   fc'         173 non-null    float64
#  4   rohsx       173 non-null    float64
#  5   fsx         173 non-null    float64
#  6   rohsy       173 non-null    float64
#  7   fsy         173 non-null    float64
#  8   Fiber type  173 non-null    int64
#  9   Ef          173 non-null    float64
#  10  ffu         173 non-null    int64
#  11  WS          173 non-null    int64
#  12  rosf        173 non-null    float64
#  13  hfe         173 non-null    float64
#  14  V, ex       173 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 20.4 KB

# %% [markdown]
# ## Check missing data in each cell

# %%
# make sure no missing data in each cell
dataset_orig.isnull().sum()
# Out:
# b             0
# d             0
# a/d           0
# fc'           0
# rohsx         0
# fsx           0
# rohsy         0
# fsy           0
# Fiber type    0
# Ef            0
# ffu           0
# WS            0
# rosf          0
# hfe           0
# V, ex         0
# dtype: int64

# %%
missing = dataset_orig.isnull().sum()
missing[missing > 0].sort_values(ascending=False)
# Out:
# Series([], dtype: int64)

# %%
dataset_orig.dtypes
# Out:
# b               int64
# d             float64
# a/d           float64
# fc'           float64
# rohsx         float64
# fsx           float64
# rohsy         float64
# fsy           float64
# Fiber type      int64
# Ef            float64
# ffu             int64
# WS              int64
# rosf          float64
# hfe           float64
# V, ex         float64
# dtype: object

# %% [markdown]
# ## Drop NaN

# %%
dataset_orig=dataset_orig.dropna()

# %%
# make sure no missing data in each cell
dataset_orig.isnull().sum()
# Out:
# b             0
# d             0
# a/d           0
# fc'           0
# rohsx         0
# fsx           0
# rohsy         0
# fsy           0
# Fiber type    0
# Ef            0
# ffu           0
# WS            0
# rosf          0
# hfe           0
# V, ex         0
# dtype: int64

# %% [markdown]
# ## Drop values with zero that shouldn't be zero

# %%
dataset_orig.describe().T
# Out:
#             count         mean          std     min          25%          50%  \
# b           173.0   159.907514    41.175074  102.00   150.000000   150.000000
# d           173.0   275.853446    66.412386  159.00   230.000000   272.727273
# a/d         173.0     2.716739     0.464327    1.60     2.500000     2.690000
# fc'         173.0    30.525491    10.143784   10.10    23.300000    29.130000
# rohsx       173.0     2.689005     1.319031    0.75     1.600000     2.600000
# fsx         173.0   543.778439    44.322607  457.21   515.000000   545.000000
# rohsy       173.0     0.092665     0.157237    0.00     0.000000     0.000000
# fsy         173.0   128.988439   203.507505    0.00     0.000000     0.000000
# Fiber type  173.0     2.687861     1.331952    1.00     2.000000     2.000000
# Ef          173.0   192.365318    71.053738   31.90   190.000000   225.000000
# ffu         173.0  3393.213873  1496.182466  574.00  2800.000000  3800.000000
# WS          173.0     1.670520     0.471389    1.00     1.000000     2.000000
# rosf        173.0     1.693411     1.418706    0.20     0.600000     1.300000
# hfe         173.0   249.443824    59.754639  143.10   207.000000   245.454545
# V, ex       173.0   142.457689    84.647756   32.40    68.861096   114.394737
#
#                     75%          max
# b            180.000000   300.000000
# d            320.000000   419.000000
# a/d            3.000000     4.900000
# fc'           35.200000    61.000000
# rohsx          3.716395     6.155700
# fsx          578.000000   690.000000
# rohsy          0.210000     0.750000
# fsy          276.000000   527.000000
# Fiber type     3.000000     5.000000
# Ef           240.000000   270.000000
# ffu         4300.000000  5800.000000
# WS             2.000000     2.000000
# rosf           2.461000     6.803922
# hfe          288.000000   377.100000
# V, ex        206.850000   385.500000

# %% [markdown]
# # Drop more with specific function

# %%
# dataset_orig = dataset_orig[dataset_orig['V (kN)']<2000]
# dataset_orig = dataset_orig[dataset_orig['fyt (MPa)']!=0]
# dataset_orig = dataset_orig[dataset_orig['VMAX (kN)']!=0]
# dataset_orig = dataset_orig[dataset_orig['Vol Trans Reinf Ratio']!=0]

# %%
dataset_orig.describe().to_excel("Results/Numeric/Descriptive statistics.xlsx")

dataset_orig.describe().T
# Out:
#             count         mean          std     min          25%          50%  \
# b           173.0   159.907514    41.175074  102.00   150.000000   150.000000
# d           173.0   275.853446    66.412386  159.00   230.000000   272.727273
# a/d         173.0     2.716739     0.464327    1.60     2.500000     2.690000
# fc'         173.0    30.525491    10.143784   10.10    23.300000    29.130000
# rohsx       173.0     2.689005     1.319031    0.75     1.600000     2.600000
# fsx         173.0   543.778439    44.322607  457.21   515.000000   545.000000
# rohsy       173.0     0.092665     0.157237    0.00     0.000000     0.000000
# fsy         173.0   128.988439   203.507505    0.00     0.000000     0.000000
# Fiber type  173.0     2.687861     1.331952    1.00     2.000000     2.000000
# Ef          173.0   192.365318    71.053738   31.90   190.000000   225.000000
# ffu         173.0  3393.213873  1496.182466  574.00  2800.000000  3800.000000
# WS          173.0     1.670520     0.471389    1.00     1.000000     2.000000
# rosf        173.0     1.693411     1.418706    0.20     0.600000     1.300000
# hfe         173.0   249.443824    59.754639  143.10   207.000000   245.454545
# V, ex       173.0   142.457689    84.647756   32.40    68.861096   114.394737
#
#                     75%          max
# b            180.000000   300.000000
# d            320.000000   419.000000
# a/d            3.000000     4.900000
# fc'           35.200000    61.000000
# rohsx          3.716395     6.155700
# fsx          578.000000   690.000000
# rohsy          0.210000     0.750000
# fsy          276.000000   527.000000
# Fiber type     3.000000     5.000000
# Ef           240.000000   270.000000
# ffu         4300.000000  5800.000000
# WS             2.000000     2.000000
# rosf           2.461000     6.803922
# hfe          288.000000   377.100000
# V, ex        206.850000   385.500000

# %% [markdown]
# ## Column names

# %%
dataset_orig.columns
# Out:
# Index(['b', 'd', 'a/d', 'fc'', 'rohsx', 'fsx', 'rohsy', 'fsy', 'Fiber type',
#        'Ef', 'ffu', 'WS', 'rosf', 'hfe', 'V, ex'],
#       dtype='object')

# %% [markdown]
# ## Add extra column (columns)

# %% [markdown]
# <b> Example: Add one more column to identify specimens with or without stirrups

# %%
# df2 = dataset.copy(deep=True)
# def lab(data2):
#     if data2["rohsy"] == 0:
#         return "No stirrup"
#     if data2["rosf"] > 0:
#         return "With stirrups"
       
# df2["stirrup"] = df2.apply(lambda df2:lab(df2) ,axis =1)

# %%
# df2

# %%
# df2.info

# %%
dataset_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173 entries, 0 to 172
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   b           173 non-null    int64
#  1   d           173 non-null    float64
#  2   a/d         173 non-null    float64
#  3   fc'         173 non-null    float64
#  4   rohsx       173 non-null    float64
#  5   fsx         173 non-null    float64
#  6   rohsy       173 non-null    float64
#  7   fsy         173 non-null    float64
#  8   Fiber type  173 non-null    int64
#  9   Ef          173 non-null    float64
#  10  ffu         173 non-null    int64
#  11  WS          173 non-null    int64
#  12  rosf        173 non-null    float64
#  13  hfe         173 non-null    float64
#  14  V, ex       173 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 21.6 KB

# %% [markdown]
# ## Drop irrelevant columns from the dataset or select important columns
# [drop columns](https://www.shanelynn.ie/using-pandas-dataframe-creating-editing-viewing-data-in-python/#:~:text=To%20delete%20rows%20and%20columns,the%20%E2%80%9Caxis%E2%80%9D%20as%201.)
#
# [youtube](https://www.youtube.com/watch?v=lWB12gP2NAc)

# %%
dataset_orig.columns
# Out:
# Index(['b', 'd', 'a/d', 'fc'', 'rohsx', 'fsx', 'rohsy', 'fsy', 'Fiber type',
#        'Ef', 'ffu', 'WS', 'rosf', 'hfe', 'V, ex'],
#       dtype='object')

# %% [markdown]
# ### Drop columns

# %%
# # drop irrelevant columns from the dataset if there is any using teh code below
# drop_list = ['References', 'Clear Cover cc [in.]', 'pv (trans. reinf. ratio)', 
#              'Test configuration', 'a [in.]', 'Section depth (h) [in.]']
# dataset_orig = dataset_orig.drop(labels=drop_list, axis=1)
# dataset_orig.head()
# dataset_orig.describe().T

# %% [markdown]
# ## [Select a specific or multiple columns](https://stackoverflow.com/questions/11285613/selecting-multiple-columns-in-a-pandas-dataframe)

# %%
# # select specific column by its name
# dataset['b']

# %%
# # select specific column by its name
# dataset[['b', 'd']]

# %% [markdown]
# ## Normality test
# Check if dataset is normal:

# %%
test_normality = lambda x: stats.shapiro(x.fillna(0))[1] < 0.01
normal = pd.DataFrame(dataset_orig)
normal = normal.apply(test_normality)
print('Is dataset normal?', not normal.any())
# Out:
# Is dataset normal? False

# %% [markdown]
# ## Select a specific or multiple column using the column index

# %%
# dataset_orig.iloc[:, 0:4] # the first to 4th column

# %% [markdown]
#  ### [Count number of columns of a DataFrame](https://www.w3resource.com/python-exercises/pandas/python-pandas-data-frame-exercise-57.php)

# %%
len(dataset_orig.columns)
# Out:
# 15

# %%
dataset_orig.shape
# Out:
# (173, 15)

# %% [markdown]
# # [Identify outliers](https://www.statology.org/grubbs-test-python/#:~:text=Grubbs'%20Test%20is%20used%20to,have%20at%20least%207%20observations.)

# %%
# pip install outlier_utils
import numpy as np
from outliers import smirnov_grubbs as grubbs

for i in range(dataset_orig.shape[1]):
    outl = grubbs.max_test_indices(dataset_orig.iloc[:,i].values.flatten(), alpha=.05);
    print(outl)
print("the indices of the outliers are given above")
# Out:
# [18, 19, 20, 21, 22, 23]
# []
# [118]
# []
# []
# []
# [51, 54]
# []
# []
# []
# []
# []
# [37]
# []
# []
# the indices of the outliers are given above

# %% [markdown]
# # Final dataset to use in the network

# %%
out_index = [113
             
             
            ]
                       
dataset_no_outliers = dataset_orig.drop(out_index) # dataset without outlier (s)

# Decide which one to use for the network (Select one of the following: orignal datasest or dataset without outliers)

dataset = dataset_orig
# dataset = dataset_no_outliers

dataset.describe().T
# Out:
#             count         mean          std     min          25%          50%  \
# b           173.0   159.907514    41.175074  102.00   150.000000   150.000000
# d           173.0   275.853446    66.412386  159.00   230.000000   272.727273
# a/d         173.0     2.716739     0.464327    1.60     2.500000     2.690000
# fc'         173.0    30.525491    10.143784   10.10    23.300000    29.130000
# rohsx       173.0     2.689005     1.319031    0.75     1.600000     2.600000
# fsx         173.0   543.778439    44.322607  457.21   515.000000   545.000000
# rohsy       173.0     0.092665     0.157237    0.00     0.000000     0.000000
# fsy         173.0   128.988439   203.507505    0.00     0.000000     0.000000
# Fiber type  173.0     2.687861     1.331952    1.00     2.000000     2.000000
# Ef          173.0   192.365318    71.053738   31.90   190.000000   225.000000
# ffu         173.0  3393.213873  1496.182466  574.00  2800.000000  3800.000000
# WS          173.0     1.670520     0.471389    1.00     1.000000     2.000000
# rosf        173.0     1.693411     1.418706    0.20     0.600000     1.300000
# hfe         173.0   249.443824    59.754639  143.10   207.000000   245.454545
# V, ex       173.0   142.457689    84.647756   32.40    68.861096   114.394737
#
#                     75%          max
# b            180.000000   300.000000
# d            320.000000   419.000000
# a/d            3.000000     4.900000
# fc'           35.200000    61.000000
# rohsx          3.716395     6.155700
# fsx          578.000000   690.000000
# rohsy          0.210000     0.750000
# fsy          276.000000   527.000000
# Fiber type     3.000000     5.000000
# Ef           240.000000   270.000000
# ffu         4300.000000  5800.000000
# WS             2.000000     2.000000
# rosf           2.461000     6.803922
# hfe          288.000000   377.100000
# V, ex        206.850000   385.500000

# %%
dataset.shape
# Out:
# (173, 15)

# %% [markdown]
# # Descriptive statistics on the data

# %%
# statistics on each data
dataset.describe().T
# Out:
#             count         mean          std     min          25%          50%  \
# b           173.0   159.907514    41.175074  102.00   150.000000   150.000000
# d           173.0   275.853446    66.412386  159.00   230.000000   272.727273
# a/d         173.0     2.716739     0.464327    1.60     2.500000     2.690000
# fc'         173.0    30.525491    10.143784   10.10    23.300000    29.130000
# rohsx       173.0     2.689005     1.319031    0.75     1.600000     2.600000
# fsx         173.0   543.778439    44.322607  457.21   515.000000   545.000000
# rohsy       173.0     0.092665     0.157237    0.00     0.000000     0.000000
# fsy         173.0   128.988439   203.507505    0.00     0.000000     0.000000
# Fiber type  173.0     2.687861     1.331952    1.00     2.000000     2.000000
# Ef          173.0   192.365318    71.053738   31.90   190.000000   225.000000
# ffu         173.0  3393.213873  1496.182466  574.00  2800.000000  3800.000000
# WS          173.0     1.670520     0.471389    1.00     1.000000     2.000000
# rosf        173.0     1.693411     1.418706    0.20     0.600000     1.300000
# hfe         173.0   249.443824    59.754639  143.10   207.000000   245.454545
# V, ex       173.0   142.457689    84.647756   32.40    68.861096   114.394737
#
#                     75%          max
# b            180.000000   300.000000
# d            320.000000   419.000000
# a/d            3.000000     4.900000
# fc'           35.200000    61.000000
# rohsx          3.716395     6.155700
# fsx          578.000000   690.000000
# rohsy          0.210000     0.750000
# fsy          276.000000   527.000000
# Fiber type     3.000000     5.000000
# Ef           240.000000   270.000000
# ffu         4300.000000  5800.000000
# WS             2.000000     2.000000
# rosf           2.461000     6.803922
# hfe          288.000000   377.100000
# V, ex        206.850000   385.500000

# %%
plt.figure(figsize=(12,8))
sns.heatmap(round(dataset.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f", cmap='coolwarm')
plt.xticks(fontsize=20)
plt.yticks(fontsize=12)
plt.title("Variables summary")
plt.show();

# %%
# sns.distplot(dataset.iloc[:,-1:])  # the last column which is the output layer

# %%
# Let us check the skewness:
print("Skewness = ",dataset.iloc[:,-1:].skew())
# Out:
# Skewness =  V, ex    0.830806
# dtype: float64

# %%
# include only necessary data or exclude unnecessary columns from the data, in case there are unneccessary columns

#dataset = dataset.iloc[:, 0:12]  # include only the first 11 columns
#dataset

# %% [markdown]
# # Correlation
#
# ## [Correlation Matrix](https://www.geeksforgeeks.org/python-pandas-dataframe-corr/)
# [youtube tutorial](https://www.youtube.com/watch?v=UgtjatBt3vY)
#
# [Pearson coefficient](https://en.wikipedia.org/wiki/Pearson_correlation_coefficient)

# %%
dataset.corr()
# Out:
#                    b         d       a/d       fc'     rohsx       fsx  \
# b           1.000000  0.350726 -0.009645  0.327782 -0.127424 -0.104156
# d           0.350726  1.000000 -0.097920  0.284776  0.175339  0.001630
# a/d        -0.009645 -0.097920  1.000000  0.377885  0.554487 -0.241514
# fc'         0.327782  0.284776  0.377885  1.000000  0.354823 -0.194220
# rohsx      -0.127424  0.175339  0.554487  0.354823  1.000000 -0.084160
# fsx        -0.104156  0.001630 -0.241514 -0.194220 -0.084160  1.000000
# rohsy      -0.042403  0.087602  0.329590  0.389800  0.608152 -0.295229
# fsy        -0.124750  0.001098  0.418327  0.337032  0.682889 -0.309899
# Fiber type  0.324287  0.005072 -0.186613 -0.012145 -0.042032  0.244968
# Ef          0.123749  0.053198  0.017886  0.242030  0.081560 -0.175841
# ffu         0.111296 -0.104841 -0.000127  0.258753  0.004405 -0.196246
# WS         -0.066280 -0.060515  0.152648 -0.277157  0.078501 -0.192182
# rosf       -0.316436 -0.086342 -0.069299 -0.340333  0.168501  0.101251
# hfe         0.308035  0.921426 -0.025338  0.397011  0.207448 -0.078988
# V, ex       0.274267  0.600642  0.134589  0.565765  0.588048 -0.038580
#
#                rohsy       fsy  Fiber type        Ef       ffu        WS  \
# b          -0.042403 -0.124750    0.324287  0.123749  0.111296 -0.066280
# d           0.087602  0.001098    0.005072  0.053198 -0.104841 -0.060515
# a/d         0.329590  0.418327   -0.186613  0.017886 -0.000127  0.152648
# fc'         0.389800  0.337032   -0.012145  0.242030  0.258753 -0.277157
# rohsx       0.608152  0.682889   -0.042032  0.081560  0.004405  0.078501
# fsx        -0.295229 -0.309899    0.244968 -0.175841 -0.196246 -0.192182
# rohsy       1.000000  0.873672   -0.175986 -0.004392 -0.004078  0.136635
# fsy         0.873672  1.000000   -0.110668  0.073290  0.122574  0.285836
# Fiber type -0.175986 -0.110668    1.000000  0.100007  0.054689  0.066746
# Ef         -0.004392  0.073290    0.100007  1.000000  0.909284  0.064854
# ffu        -0.004078  0.122574    0.054689  0.909284  1.000000  0.029472
# WS          0.136635  0.285836    0.066746  0.064854  0.029472  1.000000
# rosf        0.023560 -0.057820    0.116874 -0.208193 -0.323267  0.113751
# hfe         0.172618  0.144666   -0.068655  0.133597  0.024635 -0.019021
# V, ex       0.536985  0.449149    0.134391  0.023877 -0.065084 -0.000898
#
#                 rosf       hfe     V, ex
# b          -0.316436  0.308035  0.274267
# d          -0.086342  0.921426  0.600642
# a/d        -0.069299 -0.025338  0.134589
# fc'        -0.340333  0.397011  0.565765
# rohsx       0.168501  0.207448  0.588048
# fsx         0.101251 -0.078988 -0.038580
# rohsy       0.023560  0.172618  0.536985
# fsy        -0.057820  0.144666  0.449149
# Fiber type  0.116874 -0.068655  0.134391
# Ef         -0.208193  0.133597  0.023877
# ffu        -0.323267  0.024635 -0.065084
# WS          0.113751 -0.019021 -0.000898
# rosf        1.000000 -0.196230  0.118893
# hfe        -0.196230  1.000000  0.640739
# V, ex       0.118893  0.640739  1.000000

# %% [markdown]
# <b> Another style of correlation matrix color map/heat map

# %%
dataset.corr().style.background_gradient(cmap='coolwarm') # default is pearson correlation
# Out:
# <style  type="text/css" >
# #T_7afd0_row0_col0,#T_7afd0_row1_col1,#T_7afd0_row2_col2,#T_7afd0_row3_col3,#T_7afd0_row4_col4,#T_7afd0_row5_col5,#T_7afd0_row6_col6,#T_7afd0_row7_col7,#T_7afd0_row8_col8,#T_7afd0_row9_col9,#T_7afd0_row10_col10,#T_7afd0_row11_col11,#T_7afd0_row12_col12,#T_7afd0_row13_col13,#T_7afd0_row14_col14{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_7afd0_row0_col1{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_7afd0_row0_col2,#T_7afd0_row2_col9,#T_7afd0_row2_col14,#T_7afd0_row8_col14,#T_7afd0_row9_col4,#T_7afd0_row10_col13{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_7afd0_row0_col3,#T_7afd0_row3_col2{
#             background-color:  #dcdddd;
#             color:  #000000;
#         }#T_7afd0_row0_col4,#T_7afd0_row2_col8,#T_7afd0_row3_col11,#T_7afd0_row3_col12,#T_7afd0_row5_col2,#T_7afd0_row5_col6,#T_7afd0_row5_col7,#T_7afd0_row7_col5,#T_7afd0_row10_col1,#T_7afd0_row10_col14,#T_7afd0_row12_col0,#T_7afd0_row12_col3,#T_7afd0_row12_col9,#T_7afd0_row12_col10,#T_7afd0_row12_col13{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_7afd0_row0_col5{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_7afd0_row0_col6,#T_7afd0_row10_col2,#T_7afd0_row12_col7,#T_7afd0_row14_col9,#T_7afd0_row14_col10{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_7afd0_row0_col7,#T_7afd0_row2_col13,#T_7afd0_row4_col0,#T_7afd0_row9_col1{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_7afd0_row0_col8{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_7afd0_row0_col9,#T_7afd0_row9_col13{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_7afd0_row0_col10,#T_7afd0_row5_col12,#T_7afd0_row10_col7{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_7afd0_row0_col11,#T_7afd0_row1_col10{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_7afd0_row0_col12,#T_7afd0_row12_col1{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_7afd0_row0_col13{
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }#T_7afd0_row0_col14,#T_7afd0_row11_col2{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_7afd0_row1_col0,#T_7afd0_row7_col3{
#             background-color:  #dedcdb;
#             color:  #000000;
#         }#T_7afd0_row1_col2,#T_7afd0_row10_col4{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_7afd0_row1_col3{
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }#T_7afd0_row1_col4,#T_7afd0_row8_col11,#T_7afd0_row9_col11,#T_7afd0_row11_col10{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_7afd0_row1_col5,#T_7afd0_row1_col7{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_7afd0_row1_col6{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_7afd0_row1_col8,#T_7afd0_row5_col0{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_7afd0_row1_col9,#T_7afd0_row14_col11{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_7afd0_row1_col11,#T_7afd0_row6_col9{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_7afd0_row1_col12,#T_7afd0_row11_col0{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_7afd0_row1_col13{
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }#T_7afd0_row1_col14{
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }#T_7afd0_row2_col0,#T_7afd0_row7_col9{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_7afd0_row2_col1{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_7afd0_row2_col3{
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }#T_7afd0_row2_col4{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }#T_7afd0_row2_col5{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_7afd0_row2_col6,#T_7afd0_row7_col14{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_7afd0_row2_col7{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_7afd0_row2_col10,#T_7afd0_row8_col3{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_7afd0_row2_col11,#T_7afd0_row4_col13,#T_7afd0_row7_col10,#T_7afd0_row11_col12{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_7afd0_row2_col12,#T_7afd0_row13_col11{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_7afd0_row3_col0{
#             background-color:  #dadce0;
#             color:  #000000;
#         }#T_7afd0_row3_col1{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_7afd0_row3_col4{
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }#T_7afd0_row3_col5,#T_7afd0_row10_col5{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_7afd0_row3_col6{
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }#T_7afd0_row3_col7,#T_7afd0_row3_col13{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_7afd0_row3_col8,#T_7afd0_row7_col0,#T_7afd0_row11_col13{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_7afd0_row3_col9{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_7afd0_row3_col10,#T_7afd0_row7_col11{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_7afd0_row3_col14{
#             background-color:  #f1cdba;
#             color:  #000000;
#         }#T_7afd0_row4_col1{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_7afd0_row4_col2,#T_7afd0_row14_col6{
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }#T_7afd0_row4_col3{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_7afd0_row4_col5,#T_7afd0_row6_col1,#T_7afd0_row12_col14,#T_7afd0_row13_col2{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_7afd0_row4_col6{
#             background-color:  #f7ad90;
#             color:  #000000;
#         }#T_7afd0_row4_col7{
#             background-color:  #f39577;
#             color:  #000000;
#         }#T_7afd0_row4_col8{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_7afd0_row4_col9,#T_7afd0_row6_col10,#T_7afd0_row9_col8,#T_7afd0_row10_col11{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_7afd0_row4_col10,#T_7afd0_row12_col6{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_7afd0_row4_col11{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_7afd0_row4_col12{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_7afd0_row4_col14{
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }#T_7afd0_row5_col1,#T_7afd0_row5_col10,#T_7afd0_row7_col1{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_7afd0_row5_col3,#T_7afd0_row8_col13,#T_7afd0_row13_col12{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_7afd0_row5_col4{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_7afd0_row5_col8{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_7afd0_row5_col9,#T_7afd0_row5_col14{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_7afd0_row5_col11{
#             background-color:  #4f

# %%
# you can use the following to know more about the .corr(), remove the # sing and run

#data_FRCM.corr?

# %% [markdown]
# ## [Seaborn](https://seaborn.pydata.org/)

# %% [markdown]
# ### [Seaborn.pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
# sns.pairplot(dataset, diag_kind='kde')

# %% [markdown]
# ### Seaborn correlation heatmap

# %%
plt.figure(figsize=(12,8))
sns.heatmap(dataset.corr(), annot = True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Distributions of each parameter in the database

# %%
# # Note that running the following code changes the figures style and colour of all figures even in the ANN network
# # Run it once and comment before running the ANN network

# sns.set(font_scale=1.3)  
# # sns.set(rc={'axes.facecolor':'none', 'figure.facecolor':'white'})
# sns.set_style("white")
# sns.set_style("ticks")
# num = [f for f in dataset.columns if dataset.dtypes[f] != 'object'] # for all dataset type different from 'object'
# nd = pd.melt(dataset, value_vars = num)
# n1 = sns.FacetGrid (nd, col='variable', col_wrap=4, sharex=False, sharey = False,
#                    margin_titles=True
#                    )
# # n1 = n1.map(sns.distplot, 'value')
# n1 = n1.map(plt.hist, 'value')

# # hide title
# n1.set_titles(col_template="", row_template="")  # to hide the title
# n1.set_axis_labels("", "Frequency")
# n1;

# %% [markdown]
# ## Boxplot for each parameters in the database

# %%
plt.figure(figsize=(15,5))
dataset.boxplot()
plt.show();

# %%
# box plot for output 
plt.figure(figsize=(5,5))
dataset.iloc[:,-1:].boxplot()
plt.show();

# %%
# box plot for input features
plt.figure(figsize=(10,5))
dataset.iloc[:,:-1].boxplot()
plt.show();

# %% [markdown]
# # Normalize/Standardise Data
#
# Data is can be normalised or standardised to improve model performance.
# - Normalisation remaps values to fit between 0 and 1.
# - Standardisation remaps values to so that the mean of observed values is 0 and the standard deviation is 1. Standardisation assumes that the data fits a Gaussian distribution (bell curve) with a well behaved mean and standard deviation. However, data can still be standardised if this condition is not met, but may yield unreliable results.
#
# In this case, standardisation is chosen after comparing performance of the models.

# %% [markdown]
# ## [Option 1: Standardize](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html)

# %%
# normalize the inputs with MinMaxScaler
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
dataset_stn = scaler.fit_transform(dataset)  # standardized dataset

# %% [markdown]
# ### View the standardized data
#
# ### Convert the standardized numpy array data in to pandas for better view of the data.
#
# you can then also view the descriptive statistics either in table or chart as follows:

# %%
# convert the normalized array into pandas
#pd.DataFrame(inp_norm)

dataset_stn_pd = pd.DataFrame(data = dataset_stn, # values
             columns = dataset.columns)   # assign the column name of the "dataset" to the column name of the new data
dataset_stn_pd
# Out:
#             b         d       a/d       fc'     rohsx       fsx     rohsy  \
# 0   -0.241318  0.477899  1.151795  0.689561 -0.394617 -1.443137 -0.591043
# 1   -0.241318  0.477899  1.151795  0.689561 -0.394617 -1.443137 -0.591043
# 2   -0.241318  0.477899  1.151795  0.689561 -0.394617 -1.443137 -0.591043
# 3   -0.241318  0.477899  1.151795  0.738995 -0.394617 -1.443137 -0.591043
# 4   -0.241318  0.477899  1.151795  0.689561 -0.394617 -1.443137 -0.591043
# ..        ...       ...       ...       ...       ...       ...       ...
# 168 -0.241318 -0.511226  1.272286  1.525001  1.245621 -0.397753  1.118861
# 169 -0.241318 -0.511226  1.272286  1.525001  1.245621 -0.397753  1.118861
# 170 -0.241318 -0.511226  1.272286  1.525001  1.245621 -0.397753  1.118861
# 171 -0.241318 -0.511226  1.272286  1.525001  1.245621 -0.397753  1.118861
# 172 -0.241318 -0.511226  1.272286  1.525001  1.245621 -0.397753  1.118861
#
#           fsy  Fiber type        Ef       ffu        WS      rosf       hfe  \
# 0   -0.635666   -1.270887 -1.656577 -0.732790 -1.426565 -0.754096  0.458298
# 1   -0.635666   -1.270887 -1.656577 -0.732790  0.700985 -0.754096  0.458298
# 2   -0.635666   -0.517930  0.531203  0.272672 -1.426565 -0.851179  0.458298
# 3   -0.635666   -0.517930  0.531203  0.272672  0.700985 -0.851179  0.458298
# 4   -0.635666   -0.517930  0.531203  0.272672 -1.426565 -0.364823  0.458298
# ..        ...         ...       ...       ...       ...       ...       ...
# 168  1.957493    0.235027  1.095791  1.613287  0.700985 -0.955861  0.848519
# 169  1.957493    0.235027  1.095791  1.613287  0.700985 -0.955861  0.848519
# 170  1.957493    0.235027  1.095791  1.613287  0.700985 -0.955861  0.848519
# 171  1.957493    0.235027  1.095791  1.613287  0.700985 -0.955861  0.848519
# 172  1.957493    0.235027  1.095791  1.613287  0.700985 -0.955861  0.848519
#
#         V, ex
# 0   -0.821154
# 1   -0.620332
# 2   -0.766654
# 3   -0.788572
# 4   -0.234088
# ..        ...
# 168  1.259465
# 169  1.109707
# 170  1.307212
# 171  1.124398
# 172  1.025527
#
# [173 rows x 15 columns]

# %% [markdown]
# ## [Option 2: MinMaxScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html)

# %%
# normalize the inputs with MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
dataset_minmax = scaler.fit_transform(dataset)  # Normalized input data

# %% [markdown]
# ### View the normalized data
#
# ### Convert the normalized numpy array data in to pandas for better view of the data.
#
# you can then also view the descriptive statistics either in table or chart as follows:

# %%
# convert the normalized array into pandas
#pd.DataFrame(inp_norm)

dataset_minmax_pd = pd.DataFrame(data = dataset_minmax, # values
             columns = dataset.columns)   # assign the column name of the "dataset" to the column name of the new data
dataset_minmax_pd
# Out:
#             b         d       a/d       fc'     rohsx       fsx     rohsy  \
# 0    0.242424  0.571154  0.500000  0.538310  0.262686  0.097899  0.000000
# 1    0.242424  0.571154  0.500000  0.538310  0.262686  0.097899  0.000000
# 2    0.242424  0.571154  0.500000  0.538310  0.262686  0.097899  0.000000
# 3    0.242424  0.571154  0.500000  0.548134  0.262686  0.097899  0.000000
# 4    0.242424  0.571154  0.500000  0.538310  0.262686  0.097899  0.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 168  0.242424  0.319231  0.516905  0.704322  0.661757  0.296362  0.357443
# 169  0.242424  0.319231  0.516905  0.704322  0.661757  0.296362  0.357443
# 170  0.242424  0.319231  0.516905  0.704322  0.661757  0.296362  0.357443
# 171  0.242424  0.319231  0.516905  0.704322  0.661757  0.296362  0.357443
# 172  0.242424  0.319231  0.516905  0.704322  0.661757  0.296362  0.357443
#
#           fsy  Fiber type        Ef       ffu   WS      rosf       hfe  \
# 0    0.000000        0.00  0.181016  0.330272  0.0  0.064608  0.571154
# 1    0.000000        0.00  0.181016  0.330272  1.0  0.064608  0.571154
# 2    0.000000        0.25  0.832003  0.617298  0.0  0.043812  0.571154
# 3    0.000000        0.25  0.832003  0.617298  1.0  0.043812  0.571154
# 4    0.000000        0.25  0.832003  0.617298  0.0  0.147993  0.571154
# ..        ...         ...       ...       ...  ...       ...       ...
# 168  0.998482        0.50  1.000000  1.000000  1.0  0.021389  0.670513
# 169  0.998482        0.50  1.000000  1.000000  1.0  0.021389  0.670513
# 170  0.998482        0.50  1.000000  1.000000  1.0  0.021389  0.670513
# 171  0.998482        0.50  1.000000  1.000000  1.0  0.021389  0.670513
# 172  0.998482        0.50  1.000000  1.000000  1.0  0.021389  0.670513
#
#         V, ex
# 0    0.115406
# 1    0.163410
# 2    0.128434
# 3    0.123195
# 4    0.255735
# ..        ...
# 168  0.612744
# 169  0.576947
# 170  0.624157
# 171  0.580459
# 172  0.556825
#
# [173 rows x 15 columns]

# %% [markdown]
# ## Select which one to use: Standardized or MinMax ?

# %%
# Select which one to use for the next steps
# choose between: dataset_norm_pd and dataset_minmax_pd
# dataset_n = dataset_stn_pd # standardized normal
dataset_n = dataset_minmax_pd # MinMaxScaler
dataset_n
# Out:
#             b         d       a/d       fc'     rohsx       fsx     rohsy  \
# 0    0.242424  0.571154  0.500000  0.538310  0.262686  0.097899  0.000000
# 1    0.242424  0.571154  0.500000  0.538310  0.262686  0.097899  0.000000
# 2    0.242424  0.571154  0.500000  0.538310  0.262686  0.097899  0.000000
# 3    0.242424  0.571154  0.500000  0.548134  0.262686  0.097899  0.000000
# 4    0.242424  0.571154  0.500000  0.538310  0.262686  0.097899  0.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 168  0.242424  0.319231  0.516905  0.704322  0.661757  0.296362  0.357443
# 169  0.242424  0.319231  0.516905  0.704322  0.661757  0.296362  0.357443
# 170  0.242424  0.319231  0.516905  0.704322  0.661757  0.296362  0.357443
# 171  0.242424  0.319231  0.516905  0.704322  0.661757  0.296362  0.357443
# 172  0.242424  0.319231  0.516905  0.704322  0.661757  0.296362  0.357443
#
#           fsy  Fiber type        Ef       ffu   WS      rosf       hfe  \
# 0    0.000000        0.00  0.181016  0.330272  0.0  0.064608  0.571154
# 1    0.000000        0.00  0.181016  0.330272  1.0  0.064608  0.571154
# 2    0.000000        0.25  0.832003  0.617298  0.0  0.043812  0.571154
# 3    0.000000        0.25  0.832003  0.617298  1.0  0.043812  0.571154
# 4    0.000000        0.25  0.832003  0.617298  0.0  0.147993  0.571154
# ..        ...         ...       ...       ...  ...       ...       ...
# 168  0.998482        0.50  1.000000  1.000000  1.0  0.021389  0.670513
# 169  0.998482        0.50  1.000000  1.000000  1.0  0.021389  0.670513
# 170  0.998482        0.50  1.000000  1.000000  1.0  0.021389  0.670513
# 171  0.998482        0.50  1.000000  1.000000  1.0  0.021389  0.670513
# 172  0.998482        0.50  1.000000  1.000000  1.0  0.021389  0.670513
#
#         V, ex
# 0    0.115406
# 1    0.163410
# 2    0.128434
# 3    0.123195
# 4    0.255735
# ..        ...
# 168  0.612744
# 169  0.576947
# 170  0.624157
# 171  0.580459
# 172  0.556825
#
# [173 rows x 15 columns]

# %%
dataset.iloc[:,-1]
# Out:
# 0       73.150
# 1       90.100
# 2       77.750
# 3       75.900
# 4      122.700
#         ...
# 168    248.760
# 169    236.120
# 170    252.790
# 171    237.360
# 172    229.015
# Name: V, ex, Length: 173, dtype: float64

# %% [markdown]
# # Plot output versus all input parameters

# %%
# dataset = dataset.drop(['L1'], axis=1)  # drop some column by column name

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173 entries, 0 to 172
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   b           173 non-null    int64
#  1   d           173 non-null    float64
#  2   a/d         173 non-null    float64
#  3   fc'         173 non-null    float64
#  4   rohsx       173 non-null    float64
#  5   fsx         173 non-null    float64
#  6   rohsy       173 non-null    float64
#  7   fsy         173 non-null    float64
#  8   Fiber type  173 non-null    int64
#  9   Ef          173 non-null    float64
#  10  ffu         173 non-null    int64
#  11  WS          173 non-null    int64
#  12  rosf        173 non-null    float64
#  13  hfe         173 non-null    float64
#  14  V, ex       173 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 25.7 KB

# %% [markdown]
# ## input features names

# %%
# input variabels names
names = ['b (mm)',
         'd (mm)',
         'a/d',
         r'$f_{c}$'+' (MPa)',
         r'$\rho_{sx}$'+' (%)',
         r'$f_{sx}$'+' (MPa)',
         r'$\rho_{sy}$'+' (%)',
         r'$f_{sy}$'+' (MPa)',
         'Fiber type',
         r'$E_{f}$'+' (GPa)',
         r'$f_{fu}$'+' (MPa)',
         'Wrapping scheme',
         r'$\rho_{sf}$'+' (%)',
         r'$h_{fe}$'+' (mm)',         
           

        ]

# %%
fontsz = 18
# Text font weight
fweight = 'normal'
lab = ["a","b","c","d","e","f","g","h","i","j","k","l","m","n"]
import matplotlib.font_manager
lm = 1
# colour
COLOR = 'black'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR
# font style
# matplotlib.rcParams['font.sans-serif'] = "Comic Sans MS"
plt.rcParams['font.sans-serif'] = 'DejaVu Sans'
plt.rcParams['font.style'] = 'normal'
# plt.rcParams['font.style'] = 'italic'

plt.rcParams['axes.linewidth'] = 1.3; # set the value globally
axes_style = {'linewidth':5};

# font size
fsize = 15 # font size
plt.rcParams['font.size'] = '17'  # font size of axis label

markr = ["P", "o", "v", "^", "*", "X", "D", "P", "o", "v", "^", "*", "X", "D"]


plt.figure()
plt.figure(figsize=(13,15))  # plot size
# plt.subplot(1, 2, 1)
for i in range(1,dataset.shape[1]):
    plt.subplot(5, 3, i)
    x=dataset.iloc[:,i-1]
    plt.scatter(x, dataset.iloc[:,-1], label=dataset.columns[i], c='b', marker=markr[i-1], s=30)
    
    plt.ylabel(r'$V_{exp} $' ' (kN)', fontsize=fontsz)
#     plt.xlabel(dataset.columns[i-1], fontsize=fontsz)
    plt.xlabel(names[i-1], fontsize=fontsz)
    
    plt.subplots_adjust(wspace=0.5, hspace=0.7);
    # change axis limit
    axes = plt.gca()
#     axes.set_ylim([0, lm])
#     plt.title(dataset.columns[i-1], fontsize=14)
#     # get axis limits
#     y_min, y_max = axes.get_ylim()
#     x_min, x_max = axes.get_xlim()
#     # add text: 
#     plt.text(x_max-5, y_min+5, r'(' + str(lab[i-1])+r')', horizontalalignment='center',
#          verticalalignment='center', fontsize=fsize, fontweight=fweight)
    
plt.show();

# %%
fontsz = 18
# Text font weight
fweight = 'normal'
lab = ["a","b","c","d","e","f","g","h","i","j","k","l","m","n"]
import matplotlib.font_manager
lm = 1
# colour
COLOR = 'black'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR
# font style
# matplotlib.rcParams['font.sans-serif'] = "Comic Sans MS"
plt.rcParams['font.sans-serif'] = 'DejaVu Sans'
plt.rcParams['font.style'] = 'normal'
# plt.rcParams['font.style'] = 'italic'

plt.rcParams['axes.linewidth'] = 1.3; # set the value globally
axes_style = {'linewidth':5};

# font size
fsize = 15 # font size
plt.rcParams['font.size'] = '17'  # font size of axis label

markr = ["P", "o", "v", "^", "*", "X", "D", "P", "o", "v", "^", "*", "X", "D"]



plt.figure()
plt.figure(figsize=(13,9))  # plot size
# plt.subplot(1, 2, 1)
for i in range(1,dataset.shape[1]):
    plt.subplot(5, 3, i)
    x=dataset.iloc[:,i-1]
    plt.bar(np.arange(len(x)), x, label=dataset.columns[i])
    
#     plt.ylabel(r'$V_{ex} $' ' (kN)', fontsize=fontsz)
#     plt.xlabel(dataset.columns[i-1], fontsize=fontsz)
    plt.ylabel(names[i-1], fontsize=fontsz)
    
    plt.subplots_adjust(wspace=0.5, hspace=0.7);
    # change axis limit
    axes = plt.gca()
#     axes.set_ylim([0, lm])
#     plt.title(dataset.columns[i-1], fontsize=14)
#     # get axis limits
#     y_min, y_max = axes.get_ylim()
#     x_min, x_max = axes.get_xlim()
#     # add text: 
#     plt.text(x_max-5, y_min+5, r'(' + str(lab[i-1])+r')', horizontalalignment='center',
#          verticalalignment='center', fontsize=fsize, fontweight=fweight)
    
plt.show();
